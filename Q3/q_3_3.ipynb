# %%
import pandas as pd
import io
import numpy
df = pd.read_csv('Traffic.csv')

final = pd.DataFrame(df.COAL)
print(final)
final.boxplot(figsize=(5,5),fontsize='8',grid=False)
q3,q1 = numpy.percentile(final,[75,25])
iqr = q3 - q1
lf=q1-1.5*iqr
uf=q3+1.5*iqr
print("Lower fence ",lf)
print("Upper fence ",uf)

final.describe()
# Out:
#      COAL
# 0    3401
# 1    8485
# 2    9277
# 3    8856
# 4    8387
# 5    8802
# 6    9051
# 7    9708
# 8    9279
# 9    9368
# 10  13111
# 11  14925
# 12  22482
# 13  24222
# 14  25612
# 15  23096
# 16  23172
# 17  25003
# 18  20266
# 19      0
# Lower fence  -11847.0
# Upper fence  43325.0
#                COAL
# count     20.000000
# mean   13825.150000
# std     7854.605778
# min        0.000000
# 25%     8842.500000
# 50%     9538.000000
# 75%    22635.500000
# max    25612.000000

# %% [markdown]
# There is no outlier in the dataset .
#
# Since the Lower and Upper fence values lies between -11847.0
# and 43325.0
